# %%
import pandas as pd
import soccerdata as sd
pd.set_option('display.max_columns', None)

# %%
fotmob = sd.Understat(seasons='24')
# Out:
# [06/18/24 20:42:30] INFO     Saving cached data to /Users/caseyromkes/soccerdata/data/Understat      ]8;id=515718;file:///opt/homebrew/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=640578;file:///opt/homebrew/lib/python3.12/site-packages/soccerdata/_common.py#263\263]8;;\

# %% [markdown]
# ## let's get some leagues

# %%
leagues = fotmob.read_leagues()
print (leagues)
# Out:
#                    league_id                                      url
# league
# ENG-Premier League         1         https://understat.com/league/EPL
# ESP-La Liga                4     https://understat.com/league/La_liga
# ITA-Serie A                2     https://understat.com/league/Serie_A
# GER-Bundesliga             3  https://understat.com/league/Bundesliga
# FRA-Ligue 1                5     https://understat.com/league/Ligue_1

# %%
schedule = fotmob.read_schedule()
print (schedule)
# Out:
#                                                                                    round  \
# league                    season game
# INT-European Championship 2024   2024-06-14 Germany-Scotland                           1
#                                  2024-06-15 Hungary-Switzerland                        1
#                                  2024-06-15 Italy-Albania                              1
#                                  2024-06-15 Spain-Croatia                              1
#                                  2024-06-16 Poland-Netherlands                         1
#                                  2024-06-16 Serbia-England                             1
#                                  2024-06-16 Slovenia-Denmark                           1
#                                  2024-06-17 Austria-France                             1
#                                  2024-06-17 Belgium-Slovakia                           1
# ...

# %% [markdown]
# Just getting info for the Dutch team

# %%
results = fotmob.read_team_match_stats(team='Netherlands')
print (results)
# Out:
# [06/18/24 20:29:55] INFO     [1/1] Retrieving game with id=4043855                                    ]8;id=60104;file:///opt/homebrew/lib/python3.12/site-packages/soccerdata/fotmob.py\fotmob.py]8;;\:]8;id=237125;file:///opt/homebrew/lib/python3.12/site-packages/soccerdata/fotmob.py#396\396]8;;\
#                                                                            Accurate passes  \
# league                    season game                          team
# INT-European Championship 2024   2024-06-16 Poland-Netherlands Netherlands             514
#                                                                Poland                  232
#
#                                                                            Ball possession  \
# league                    season game                          team
# INT-European Championship 2024   2024-06-16 Poland-Netherlands Netherlands              66
# ...
